# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datos = {
    'Nombre': ['Juan', 'Santiago', 'David', 'Camilo'], # Los datos de la fila Nombre, edad y Departamento, son las columnas para indicar el nombre de cada fila
    'Edad': [10, 20, 40, 30],
    'Departamento': ['Comunicación', 'Administración', 'Ventas','Talento Humano'],
    'Dirección': ['Los robles', 'La inmaculada', 'los cusules', 'Los girasoles']
}

tabla = pd.DataFrame(datos)
display(tabla)
# Out:
#      Nombre  Edad    Departamento      Dirección
# 0      Juan    10    Comunicación     Los robles
# 1  Santiago    20  Administración  La inmaculada
# 2     David    40          Ventas    los cusules
# 3    Camilo    30  Talento Humano  Los girasoles
